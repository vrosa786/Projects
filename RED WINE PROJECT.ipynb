# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn import metrics
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
from sklearn.metrics import roc_curve, auc

import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://raw.githubusercontent.com/vrosa786/Projects/main/winequality-red.csv'
df = pd.read_csv(url)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df['quality_binary'] = (df['quality']>=7).astype(int)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df['quality_binary'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality_binary, dtype: int64

# %%
ax=sns.countplot(x='quality_binary', data = df)
print(df['quality_binary'].value_counts())
# Out:
# 0    1382
# 1     217
# Name: quality_binary, dtype: int64

# %%
#plt.figure(figsize=(15,10),facecolor="white")
#plot_number=1
#for column in df:
 #   if plot_number<=13:
  #      ax=plt.subplot(4,4,plot_number)
   #     sns.boxplot(df[column])
    #    plt.xlabel(column,fontsize=12)
    #plot_number +=1   

#plt.tight_layout()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# quality_binary          2.129363
# Good_Vine               2.129363
# dtype: float64

# %%
filter_data_good = df[df['quality_binary']>0]
print("Good Vine Data")
filter_data_good.hist(figsize=(15,15))
plt.show()
# Out:
# Good Vine Data

# %%
filter_data_bad = df[df['quality_binary']==0]
print("Bad Vine Data")
filter_data_bad.hist(figsize=(15,15))
plt.show()
# Out:
# Bad Vine Data

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
# quality_binary             0.120061         -0.270712     0.214716
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
x = df.drop('quality', axis=1)
y = df ['quality']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state = 42)

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = clf.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.675

# %%
print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.09      0.10      0.10        10
#            5       0.68      0.70      0.69       130
#            6       0.69      0.66      0.67       132
#            7       0.88      0.88      0.88        42
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.68       320
#    macro avg       0.39      0.39      0.39       320
# weighted avg       0.68      0.68      0.68       320

# %%
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[ 0  0  0  1  0  0]
#  [ 1  1  3  5  0  0]
#  [ 1  5 91 33  0  0]
#  [ 0  5 40 87  0  0]
#  [ 0  0  0  0 37  5]
#  [ 0  0  0  0  5  0]]

# %%
y_pred_prob = rf.prdict_proba(x_test)[:,1]

fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label = 'RandomForestClassifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
auc_score = roc_auc_score(y_test,rf.predict(x_test))
print('Score: ', auc_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 y_pred_prob = rf.prdict_proba(x_test)[:,1]
#       3 fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
#       5 plt.plot([0,1],[0,1],'k--')
#
# NameError: name 'rf' is not defined

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
true_labels = y_test
predicted_probs = model.predict_proba(x_test)

fpr, tpr, thresholds = roc_curve(true_labels,predicted_probs[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 6
#       3 true_labels = y_test
#       4 predicted_probs = model.predict_proba(x_test)
# ----> 6 fpr, tpr, thresholds = roc_curve(true_labels,predicted_probs[:, 1])
#       7 roc_auc = auc(fpr, tpr)
#       9 # Plot ROC curve
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:992, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     904 def roc_curve(
#     905     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#     906 ):
#     907     """Compute Receiver operating characteristic (ROC).
#     908
#     909     Note: this implementation is restricted to the binary classification task.
#    (...)
#     990     array([1.8 , 0.8 , 0.4 , 0.35, 0.1 ])
#     991     """
# --> 992     fps, tps, thresholds = _binary_clf_curve(
# ...
